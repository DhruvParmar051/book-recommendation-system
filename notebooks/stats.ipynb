# %%
import pandas as pd
import json
import sys
from pathlib import Path

# %%
BASE_DIR = Path().resolve().parent
DATA_DIR = BASE_DIR / "data"

RAW_DIR = DATA_DIR / "raw_data"
INGESTED_DIR = DATA_DIR / "ingested_data" / 'books data.csv'
CLEAN_CSV = DATA_DIR / "clean_data" / "clean_books.csv"
ENRICHED_JSON = DATA_DIR / "enriched_data" / "enriched_books.json"

# %% [markdown]
# 📥 1. RAW DATA STATISTICS (Before Pipeline)

# %%
raw_files = list(RAW_DIR.glob("*.csv"))
raw_dfs = [pd.read_csv(f, encoding="latin1", low_memory=False) for f in raw_files]

raw_df = pd.concat(raw_dfs, ignore_index=True)

# %%
raw_stats = {
    "total_raw_rows": len(raw_df),
    "unique_titles": raw_df["Title"].nunique(dropna=True),
    "missing_titles": raw_df["Title"].isna().sum(),
    "missing_isbn": raw_df["ISBN"].isna().sum() if "ISBN" in raw_df else None,
}
raw_stats
# Out:
# {'total_raw_rows': 36364,
#  'unique_titles': 30906,
#  'missing_titles': np.int64(0),
#  'missing_isbn': np.int64(412)}

# %% [markdown]
# 📥 2. INGESTED DATA STATISTICS

# %%
ingested_df = pd.read_csv(INGESTED_DIR, encoding="latin1", low_memory=False)

# %%
ingested_stats = {
    "total_ingested_rows": len(ingested_df),
    "unique_titles": ingested_df["title"].nunique(),
    "unique_isbn": ingested_df["isbn"].nunique(dropna=True),
    "missing_isbn": ingested_df["isbn"].isna().sum(),
    "missing_year": ingested_df["year"].isna().sum(),
}
ingested_stats
# Out:
# {'total_ingested_rows': 36364,
#  'unique_titles': 30906,
#  'unique_isbn': 31546,
#  'missing_isbn': np.int64(412),
#  'missing_year': np.int64(170)}

# %% [markdown]
# 🧹 3. CLEANED DATA STATISTICS

# %%
clean_df = pd.read_csv(CLEAN_CSV)

# %%
clean_stats = {
    "total_clean_rows": len(clean_df),
    "unique_record_id": clean_df["record_id"].nunique(),
    "unique_isbn": clean_df["isbn"].nunique(dropna=True),
    "missing_isbn": clean_df["isbn"].isna().sum(),
    "duplicate_removed": len(ingested_df) - len(clean_df),
}
clean_stats
# Out:
# {'total_clean_rows': 31999,
#  'unique_record_id': 31999,
#  'unique_isbn': 26871,
#  'missing_isbn': np.int64(5075),
#  'duplicate_removed': 4365}

# %%
clean_df[clean_df["title"].duplicated()]
# Out:
#              date  accession_no  \
# 70     09-08-2001           121
# 96     15-09-2001           157
# 139    15-09-2001           285
# 170    22-09-2001           369
# 205    29-09-2001           462
# ...           ...           ...
# 31817  22-12-2010         25398
# 31831  01-02-2011         25500
# 31874  16-06-2011         26039
# 31875  16-06-2011         26040
# 31914  13-05-2013         28281
#
#                                                    title  \
# 70                                     computer graphics
# 96               high-performance communication networks
# 139                                      microprocessors
# 170                                programming languages
# 205    science, hegemony and violence : a requiem for...
# ...                                                  ...
# 31817                                      bhagavad gita
# 31831                 discrete mathematics for computing
# 31874  inside servlets : server-side programming for ...
# 31875                            java 2 network security
# 31914                                 algebraic topology
#
#                author_editor edition_volume  \
# 70        harrington, steven        2nd ed.
# 96             walrand, jean            NaN
# 139    rafiquzzaman, mohamed    revised ed.
# 170              sethi, ravi        2nd ed.
# 205             nandy, ashis            NaN
# ...                      ...            ...
# 31817       easwaran, eknath            NaN
# 31831        grossman, peter        3rd ed.
# 31874    callaway, dustin r.        2nd ed.
# 31875         pistoia, marco        2nd ed.
# 31914      spanier, edwin h.            NaN
#
#                            place_publisher           isbn    year  \
# 70                  new york: mcgraw-hill,  9780071004725  1987.0
# 96                    singapore: harcourt,     1558605746  2000.0
# 139     new delhi: prentice hall of india,     8120308484  2000.0
# 170                 delhi: addison-wesley,     8178081040  2000.0
# 205    new delhi: oxford university press,  9780195625807  1999.0
# ...                                    ...            ...     ...
# 31817               canada: nilgiri press,            NaN  2007.0
# 31831        new york: palgrave macmillan,            NaN  2009.0
# 31874              boston: addison-wesley,            NaN  2001.0
# 31875   upper saddle river: prentice hall,            NaN  1999.0
# 31914                  new york: springer,            NaN  1966.0
#
#               pages source   class_no_book_no  \
# 70          466 p.;    NaN          006.6 har
# 96          693 p.;    NaN        621.382 wal
# 139         468 p.;    NaN         004.16 raf
# 170         640 p.;    NaN          005.1 set
# 205         301 p.;    NaN          809.4 nan
# ...             ...    ...                ...
# 31817       294 p.;    NaN  294.592404521 eas
# 31831  xii, 316 p.;    NaN       004.0151 gro
# 31874  xxv, 881 p.;    NaN       005.2762 cal
# 31875  xxi, 713 p.;    NaN          005.8 pis
# 31914  xiv, 528 p.;    NaN          514.2 spa
#
#                               record_id
# 70     fdc6e18dedb7dba6242c9fe8b7fa7fad
# 96     6412802223dad6a2d714ead829e4eba6
# 139    a91946d1920476262ea4b91ac9903668
# 170    22958e628b75fdf8ce4282f1fdc6c61c
# 205    c9c845775fb6e576dfbe54c841fe0cf9
# ...                                 ...
# 31817  861542c8d7e66493c194b2e67a7ff82f
# 31831  b577b70b85595f9d13e36dd5b98cda79
# 31874  b756a96c9ab56d66ca3aee0f304b6053
# 31875  784e65991b0233fbd279e59e5e3c34ec
# 31914  2d2e04d7740957a89bd4e756bfe92207
#
# [1352 rows x 12 columns]

# %%
{
    "isbn_based_books": clean_df["isbn"].notna().sum(),
    "non_isbn_books": clean_df["isbn"].isna().sum(),
}
# Out:
# {'isbn_based_books': np.int64(26924), 'non_isbn_books': np.int64(5075)}

# %%
with open(ENRICHED_JSON, "r", encoding="utf-8") as f:
    enriched_data = json.load(f)

enriched_df = pd.DataFrame(enriched_data)

# %%
enrichment_stats = {
    "total_processed": len(enriched_df),
    "found_books": (enriched_df["status"] == "FOUND").sum(),
    "missing_books": (enriched_df["status"] == "MISSING").sum(),
    "success_rate_%": round(
        100 * (enriched_df["status"] == "FOUND").mean(), 2
    ),
}
enrichment_stats
# Out:
# {'total_processed': 31999,
#  'found_books': np.int64(5146),
#  'missing_books': np.int64(26853),
#  'success_rate_%': np.float64(16.08)}

# %%
{
    "authors_available": enriched_df["authors"].notna().sum(),
    "subjects_available": enriched_df["subjects"].notna().sum(),
    "summary_available": enriched_df["summary"].notna().sum(),
    "publisher_available": enriched_df["publisher"].notna().sum(),
}
# Out:
# {'authors_available': np.int64(5020),
#  'subjects_available': np.int64(4656),
#  'summary_available': np.int64(4301),
#  'publisher_available': np.int64(3902)}

# %%
final_stats = {
    "final_books_count": enriched_df["book_key"].nunique(),
    "unique_titles": enriched_df["title"].nunique(),
    "unique_isbn": enriched_df["isbn"].nunique(dropna=True),
}
final_stats
# Out:
# {'final_books_count': 31939, 'unique_titles': 30895, 'unique_isbn': 26251}

# %%
summary = pd.DataFrame([
    {"stage": "Raw", "rows": len(raw_df)},
    {"stage": "Ingested", "rows": len(ingested_df)},
    {"stage": "Cleaned", "rows": len(clean_df)},
    {"stage": "Enriched", "rows": len(enriched_df)},
])

summary
# Out:
#       stage   rows
# 0       Raw  36364
# 1  Ingested  36364
# 2   Cleaned  31999
# 3  Enriched  31999
